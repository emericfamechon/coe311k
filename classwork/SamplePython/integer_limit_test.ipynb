# %%
i = 2147483647
print(i)
# Out:
# 2147483647

# %%
i = i + 1
print(i)
# Out:
# 2147483648

# %%
i = 1
print(i)
# Out:
# 1

# %%
i+2**-51
# Out:
# 1.0000000000000004

# %%
i+2**-52
# Out:
# 1.0000000000000002

# %%
i+2**-53
# Out:
# 1.0
