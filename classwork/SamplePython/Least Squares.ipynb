# %%
import numpy as np
import matplotlib.pyplot as plt

X=np.array([1,2,3,4,5])
Y=np.array([1.2,2.8,3.6,4.5,5.1])

A=np.vstack([X,np.ones(len(X))]).T

print("X:")
print(X)

print("Y:")
print(Y)

print("A:")
print(A)
# Out:
# X:
# [1 2 3 4 5]
# Y:
# [1.2 2.8 3.6 4.5 5.1]
# A:
# [[1. 1.]
#  [2. 1.]
#  [3. 1.]
#  [4. 1.]
#  [5. 1.]]

# %%
m, c=np.linalg.lstsq(A,Y,rcond=None)[0]
print(f"Slope: {m}, Intercept: {c}")
# Out:
# Slope: 0.9500000000000001, Intercept: 0.5900000000000001

# %% [markdown]
# # Plot each data point
# # Plot the line y=.95*x+.59

# %%
yresult=.95*X +.59
plt.scatter(X, Y)
plt.plot(X, yresult,'k')
plt.show()

# %%
import random

# %%
Z = np.random.rand(5)*10
print(f"Uniform Vector: {Z}")
# Out:
# Uniform Vector: [4.87325664 3.30214914 9.43801401 9.30039738 2.07727778]

# %%
X=np.array([1,2,3,4,5])

A=np.vstack([X,np.ones(len(X))]).T

print("X:")
print(X)

print("Z:")
print(Z)

print("A:")
print(A)
# Out:
# X:
# [1 2 3 4 5]
# Z:
# [4.87325664 3.30214914 9.43801401 9.30039738 2.07727778]
# A:
# [[1. 1.]
#  [2. 1.]
#  [3. 1.]
#  [4. 1.]
#  [5. 1.]]

# %%
m, c=np.linalg.lstsq(A,Z,rcond=None)[0]
print(f"Slope: {m}, Intercept: {c}")
# Out:
# Slope: 0.040629054352624955, Intercept: 5.6763318271638346

# %%
zresult=m*X + c + random.uniform(0, 1)
plt.scatter(X, Z)
plt.plot(X, yresult,'k')
plt.show()
