# %% [markdown]
# importing Python libraries

# %%
import numpy as np
import math
import random
import matplotlib.pyplot as plt

# %% [markdown]
# montecarlo function (from earlier challenges done)

# %%
def montecarlo_pi(number_of_shots):
    number_of_hits = 0
    for i in range(0,number_of_shots):
        x = random.uniform(-1,1)
        y = random.uniform(-1,1)
        if ((x*x + y*y) < 1):
            number_of_hits = number_of_hits+1
    return 4 * (number_of_hits/number_of_shots)

# %% [markdown]
# main function (runs the function the desired amount of times)

# %%
#creates empty arrays to store the calculated values
truerror = []
truepi = []
steps = []

#loop that runs the montecarlo function the desired amount of times with desired steps
for i in range (10, 1000): 
    y = montecarlo_pi(i)
    truepi = np.pi
    truerror = np.append(truerror, abs(y-truepi))
    steps = np.append(steps, i)
    i = i+20

# %% [markdown]
# plots the results on a grapsh

# %%
plt.plot(steps, truerror)
